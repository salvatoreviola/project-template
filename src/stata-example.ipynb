# %%
# import stata files
import pandas as pd
import stata_setup

from config import DATA_PATH, OUTPUT_PATH

# %%
stata_setup.config("/usr/local/stata19", "se")

# %%
from pystata import stata
from sfi import Macro

Macro.setGlobal("output_path", f"{OUTPUT_PATH}")

# %%
# %%stata
# di "$output_path"

# %%
# Load a dataset (df) in python before pushing to Stata in next frame

df.read_csv("path/to/your/data.csv")

# %%
# %%stata -d df -force
# describe
