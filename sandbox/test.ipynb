# %%
from src.config import DATA_PATH

# %%
import os, sys
print(os.getcwd())
print(sys.path[:5])
# Out:
# /home/salva/Documents/project-template
# ['/home/salva/Documents/project-template', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '']
